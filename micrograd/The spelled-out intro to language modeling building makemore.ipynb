# %%
words = open("files/names.txt").read().splitlines()
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
len(words)
# Out:
# 32033

# %%
min(len(w) for w in words)
# Out:
# 2

# %%
max(len(w) for w in words)
# Out:
# 15
